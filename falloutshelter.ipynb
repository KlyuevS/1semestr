# %%
class falloutshelter():
    def __init__(self,name,health,satiety,power,endurance,charisma,intelligence):
        self.name=name
        self.health=health #здоровье
        self.satiety=satiety #сытость
        self.power=power #сила
        self.endurance=endurance #выносливость
        self.charisma=charisma #харизма
        self.intelligence=intelligence #интеллект
    def goto_gym(self):
        if self.power>0 and self.satiety>0 and self.endurance>0 and self.charisma>0 and self.health>0 and self.intelligence>0:
            print("Поздравляем!Хорошая выдалась тренировка!+10 к силе и выносливости,-10 к сытости")
            self.power=self.power+10
            self.endurance=self.endurance+10
            self.satiety=self.satiety-10
        else:
            print("Вы погибли!Используйте wannalive чтобы играть дальше!")
    def readbooks(self):
        if self.power>0 and self.satiety>0 and self.endurance>0 and self.charisma>0 and self.health>0 and self.intelligence>0:
            print("Книги развивают вас!+10 к интеллекту,-10 к сытости")
            self.intelligence=self.intelligence+10
            self.satiety=self.satiety-10
        else:
            print("Вы погибли!Используйте wannalive чтобы играть дальше!")
    def usemedicine(self):
        if self.power>0 and self.satiety>0 and self.endurance>0 and self.charisma>0 and self.health>0 and self.intelligence>0:
            print("+15 к здоровью,однако в очереди в госклинике вы знатно проголодались,-10 к сытости")
            self.health=self.health+10
            self.satiety=self.satiety-10
        else:
            print("Вы погибли!Используйте wannalive чтобы играть дальше!")
    def eatinkfc(self):
        if self.power>0 and self.satiety>0 and self.endurance>0 and self.charisma>0 and self.health>0 and self.intelligence>0:
            print("Отличный обед, однако фастфуд негативно влияет на спортивную составляющую вашего тела,-10 к силе и выносливости,+15 к сытости")
            self.satiety=self.satiety+15
            self.power=self.power-10
            self.endurance=self.enduramce-10
        else:
            print("Вы погибли!Используйте wannalive чтобы играть дальше!")
    def eatprotein(self):
        if self.power>0 and self.satiety>0 and self.endurance>0 and self.charisma>0 and self.health>0 and self.intelligence>0:
            print("Полезно и вкусно!+20 к сытости,однако общение с качками понизило вашу харизму и интеллект на 10")
            self.satiety=self.satiety+20
            self.charisma=self.charisma-10
            self.intelligence=self.intelligence-10
        else:
            print("Вы погибли!Используйте wannalive чтобы играть дальше!")
    def watchcomedy(self):
        if self.power>0 and self.satiety>0 and self.endurance>0 and self.charisma>0 and self.health>0 and self.intelligence>0:
            print("Хорошего просмотра!+10 к харизме,-5 к здоровью,-5 к выносливости")
            self.charisma=self.charisma+10
            self.health=self.health-5
            self.endurance=self.endurance-5
        else:
            print("Вы погибли!Используйте wannalive чтобы играть дальше!")
    def wannalive(self):
        
            print('Если бы это было в appstore, нужно было заплатить,однако сейчас это бесплатно!Хорошей игры!')
            self.health=50 
            self.satiety=50 
            self.power=50
            self.endurance=50
            self.charisma=50 
            self.intelligence=50 
        
            
    def mystat(self):
        print("Ваше здоровье:")
        print(self.health)
        print("Ваша сила:")
        print(self.power)
        print("Ваша выносливость:")
        print(self.endurance)
        print("Ваша сытость :")
        print(self.satiety)
        print("Ваша харизма:")
        print(self.charisma)
        print("Ваш интеллект:")
        print(self.intelligence)

# %%
persona1=falloutshelter("Sergey", 100,100,50,50,50,50)
persona1.mystat()
# Out:
# Ваше здоровье:
# 100
# Ваша сила:
# 50
# Ваша выносливость:
# 50
# Ваша сытость :
# 100
# Ваша харизма:
# 50
# Ваш интеллект:
# 50
